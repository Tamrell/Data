# %%
import pandas

SensorData = pandas.read_excel('../Final Data/Sensor Data.xlsx')

for sensor in range(1,10):
    readinds = pandas.Series(SensorData.loc[(SensorData['Monitor'] == sensor)]['Reading']).values
    timestamps = pandas.Series(SensorData.loc[(SensorData['Monitor'] == sensor)]['Date Time']).values
    print(data)
    print(timestamps)
    print('\n')
# Out:
# [0.272886 0.197804 0.144993 ... 0.670133 0.607967 0.203557]
# ['2016-04-01T00:00:00.000000000' '2016-04-01T00:00:00.000000000'
#  '2016-04-01T00:00:00.000000000' ... '2016-12-31T23:00:00.000000000'
#  '2016-12-31T23:00:00.000000000' '2016-12-31T23:00:00.000000000']
#
#
# [0.272886 0.197804 0.144993 ... 0.670133 0.607967 0.203557]
# ['2016-04-01T00:00:00.000000000' '2016-04-01T00:00:00.000000000'
#  '2016-04-01T00:00:00.000000000' ... '2016-12-31T23:00:00.000000000'
#  '2016-12-31T23:00:00.000000000' '2016-12-31T23:00:00.000000000']
#
#
# [0.272886 0.197804 0.144993 ... 0.670133 0.607967 0.203557]
# ['2016-04-01T00:00:00.000000000' '2016-04-01T00:00:00.000000000'
#  '2016-04-01T00:00:00.000000000' ... '2016-12-31T23:00:00.000000000'
#  '2016-12-31T23:00:00.000000000' '2016-12-31T23:00:00.000000000']
#
#
# [0.272886 0.197804 0.144993 ... 0.670133 0.607967 0.203557]
# ['2016-04-01T00:00:00.000000000' '2016-04-01T00:00:00.000000000'
# ...
