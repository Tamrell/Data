# %%
import pandas as pd
import numpy as np

chemicals = ['Ap', 'Ch', 'Me', 'Ag']

df = pd.read_excel("Complete Data.xlsx", index_col='Timestamp')

hist = df['Wind Speed'].hist()
hist.set_xlabel('Wind Speed')
hist.set_ylabel('Occurance')
hist.set_title('Histogram of wind speed readings')
# print([i for i in df])
# print(sum(df['Agoc']))
# Out:
# Text(0.5,1,'Histogram of wind speed readings')
