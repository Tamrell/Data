# %%
import pandas as pd
import numpy as np

chemicals = ['Ap', 'Ch', 'Me', 'Ag']

df = pd.read_excel("Complete Data.xlsx", index_col='Timestamp')

df['2016-04']['Wind Speed Linear'].plot()
df['2016-04-01']['Wind Speed Spline'].plot()
df['2016-04-02']['Wind Speed Linear'].plot()
df['2016-04-02']['Wind Speed Spline'].plot()
df['2016-04-03']['Wind Speed Linear'].plot()
df['2016-04-03']['Wind Speed Spline'].plot()

# print([i for i in df])
# print(sum(df['Agoc']))
